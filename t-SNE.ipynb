# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
import pandas as pd
import seaborn as sns

# %%
means = np.loadtxt(r'.\Clustering_Info\Clustering_Means_321.txt')
print(means.shape)
# Out:
# (8, 321)

# %%
cluster_1 = np.loadtxt(r'C:\Users\vpatro\Desktop\Final_Spectra\321\Cl_1_321.txt')
cluster_2 = np.loadtxt(r'C:\Users\vpatro\Desktop\Final_Spectra\321\Cl_2_321.txt')
cluster_3 = np.loadtxt(r'C:\Users\vpatro\Desktop\Final_Spectra\321\Cl_3_321.txt')
cluster_4 = np.loadtxt(r'C:\Users\vpatro\Desktop\Final_Spectra\321\Cl_4_321.txt')
cluster_5 = np.loadtxt(r'C:\Users\vpatro\Desktop\Final_Spectra\321\Cl_5_321.txt')
cluster_6 = np.loadtxt(r'C:\Users\vpatro\Desktop\Final_Spectra\321\Cl_6_321.txt')
cluster_7 = np.loadtxt(r'C:\Users\vpatro\Desktop\Final_Spectra\321\Cl_7_321.txt')
cluster_8 = np.loadtxt(r'C:\Users\vpatro\Desktop\Final_Spectra\321\Cl_8_321.txt')

# %%
print(cluster_1.shape)
print(cluster_2.shape)
print(cluster_3.shape)
print(cluster_4.shape)
print(cluster_5.shape)
print(cluster_6.shape)
print(cluster_7.shape)
print(cluster_8.shape)
# Out:
# (568528, 321)
# (309513, 321)
# (96485, 321)
# (220596, 321)
# (504178, 321)
# (412437, 321)
# (10377, 321)
# (72886, 321)

# %%
subsample_1_ind = np.arange(0,cluster_1.shape[0],4000)
subsample_1 = cluster_1[subsample_1_ind,:].copy()
subsample_2_ind = np.arange(0,cluster_2.shape[0],4000)
subsample_2 = cluster_2[subsample_2_ind,:].copy()
subsample_3_ind = np.arange(0,cluster_3.shape[0],4000)
subsample_3 = cluster_3[subsample_3_ind,:].copy()
subsample_4_ind = np.arange(0,cluster_4.shape[0],4000)
subsample_4 = cluster_4[subsample_4_ind,:].copy()
subsample_5_ind = np.arange(0,cluster_5.shape[0],4000)
subsample_5 = cluster_5[subsample_5_ind,:].copy()
subsample_6_ind = np.arange(0,cluster_6.shape[0],4000)
subsample_6 = cluster_6[subsample_6_ind,:].copy()
subsample_7_ind = np.arange(0,cluster_7.shape[0],4000)
subsample_7 = cluster_7[subsample_7_ind,:].copy()
subsample_8_ind = np.arange(0,cluster_8.shape[0],4000)
subsample_8 = cluster_8[subsample_8_ind,:].copy()

# %%
print(subsample_1.shape)
print(subsample_2.shape)
print(subsample_3.shape)
print(subsample_4.shape)
print(subsample_5.shape)
print(subsample_6.shape)
print(subsample_7.shape)
print(subsample_8.shape)
# Out:
# (143, 321)
# (78, 321)
# (25, 321)
# (56, 321)
# (127, 321)
# (104, 321)
# (3, 321)
# (19, 321)

# %%
model = TSNE(learning_rate = 25)

# %%
combined_subsamples = np.concatenate((subsample_1, subsample_2, subsample_3, subsample_4, \
                                     subsample_5, subsample_6, subsample_7, subsample_8, means))

# %%
combined_subsamples.shape
# Out:
# (563, 321)

# %%
transformed = model.fit_transform(combined_subsamples)
# Out:
# C:\Users\vpatro\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
transformed.shape
# Out:
# (563, 2)

# %%
xs = transformed[:,0]
ys = transformed[:,1]

# %%
df = pd.DataFrame(transformed, columns = ['Dim 1','Dim 2'])

# %%
sns.scatterplot(x = 'Dim 1', y = 'Dim 2', data = df)
# Out:
# <AxesSubplot:xlabel='Dim 1', ylabel='Dim 2'>

# %%
plt.scatter(xs[0:143],ys[0:143],color='red', alpha = 0.7)
plt.scatter(xs[143:221],ys[143:221],color='blue', alpha = 0.7)
plt.scatter(xs[221:246],ys[221:246],color='green', alpha = 0.7)
plt.scatter(xs[246:302],ys[246:302],color='purple', alpha = 0.7)
plt.scatter(xs[302:429],ys[302:429],color='orange', alpha = 0.7)
plt.scatter(xs[429:533],ys[429:533],color='yellow', alpha = 0.7)
plt.scatter(xs[533:536],ys[533:536],color='pink', alpha = 0.7)
plt.scatter(xs[536:555],ys[536:555],color='aquamarine', alpha = 0.7)
plt.scatter(xs[555:563],ys[555:563], color = 'black', alpha = 0.7)
plt.title('Learning Rate 25')
# Out:
# Text(0.5, 1.0, 'Learning Rate 25')

# %%
combined_subsamples.shape
# Out:
# (563, 321)

# %%
model = TSNE(learning_rate = 75)
transformed_75 = model.fit_transform(combined_subsamples)
print(transformed_75.shape)
xs_75 = transformed_75[:,0]
ys_75 = transformed_75[:,1]
# Out:
# C:\Users\vpatro\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# (563, 2)

# %%
plt.scatter(xs_75[0:143],ys_75[0:143],color='red', alpha = 0.7)
plt.scatter(xs_75[143:221],ys_75[143:221],color='blue', alpha = 0.7)
plt.scatter(xs_75[221:246],ys_75[221:246],color='green', alpha = 0.7)
plt.scatter(xs_75[246:302],ys_75[246:302],color='purple', alpha = 0.7)
plt.scatter(xs_75[302:429],ys_75[302:429],color='orange', alpha = 0.7)
plt.scatter(xs_75[429:533],ys_75[429:533],color='yellow', alpha = 0.7)
plt.scatter(xs_75[533:536],ys_75[533:536],color='pink', alpha = 0.7)
plt.scatter(xs_75[536:555],ys_75[536:555],color='aquamarine', alpha = 0.7)
plt.scatter(xs_75[555:563],ys_75[555:563], color = 'black', alpha = 0.7)
plt.title('Learning Rate 75')
# Out:
# Text(0.5, 1.0, 'Learning Rate 75')

# %%
combined_subsamples.shape
# Out:
# (563, 321)

# %%
model_150 = TSNE(learning_rate = 150)
transformed_150 = model_150.fit_transform(combined_subsamples)
print(transformed_150.shape)
xs_150 = transformed_150[:,0]
ys_150 = transformed_150[:,1]
# Out:
# C:\Users\vpatro\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# (563, 2)

# %%
plt.scatter(xs_150[0:143],ys_150[0:143],color='red', alpha = 0.7)
plt.scatter(xs_150[143:221],ys_150[143:221],color='blue', alpha = 0.7)
plt.scatter(xs_150[221:246],ys_150[221:246],color='green', alpha = 0.7)
plt.scatter(xs_150[246:302],ys_150[246:302],color='purple', alpha = 0.7)
plt.scatter(xs_150[302:429],ys_150[302:429],color='orange', alpha = 0.7)
plt.scatter(xs_150[429:533],ys_150[429:533],color='yellow', alpha = 0.7)
plt.scatter(xs_150[533:536],ys_150[533:536],color='pink', alpha = 0.7)
plt.scatter(xs_150[536:555],ys_150[536:555],color='aquamarine', alpha = 0.7)
plt.scatter(xs_150[555:563],ys_150[555:563], color = 'black', alpha = 0.7)
plt.title('Learning Rate 150')
# Out:
# Text(0.5, 1.0, 'Learning Rate 150')

# %%
print(cluster_1.shape)
print(cluster_2.shape)
print(cluster_3.shape)
print(cluster_4.shape)
print(cluster_5.shape)
print(cluster_6.shape)
print(cluster_7.shape)
print(cluster_8.shape)
# Out:
# (568528, 321)
# (309513, 321)
# (96485, 321)
# (220596, 321)
# (504178, 321)
# (412437, 321)
# (10377, 321)
# (72886, 321)

# %%
subsample_1_ind = np.arange(0,cluster_1.shape[0],2000)
subsample_1 = cluster_1[subsample_1_ind,:].copy()
subsample_2_ind = np.arange(0,cluster_2.shape[0],2000)
subsample_2 = cluster_2[subsample_2_ind,:].copy()
subsample_3_ind = np.arange(0,cluster_3.shape[0],2000)
subsample_3 = cluster_3[subsample_3_ind,:].copy()
subsample_4_ind = np.arange(0,cluster_4.shape[0],2000)
subsample_4 = cluster_4[subsample_4_ind,:].copy()
subsample_5_ind = np.arange(0,cluster_5.shape[0],2000)
subsample_5 = cluster_5[subsample_5_ind,:].copy()
subsample_6_ind = np.arange(0,cluster_6.shape[0],2000)
subsample_6 = cluster_6[subsample_6_ind,:].copy()
subsample_7_ind = np.arange(0,cluster_7.shape[0],2000)
subsample_7 = cluster_7[subsample_7_ind,:].copy()
subsample_8_ind = np.arange(0,cluster_8.shape[0],2000)
subsample_8 = cluster_8[subsample_8_ind,:].copy()

# %%
print(subsample_1.shape)
print(subsample_2.shape)
print(subsample_3.shape)
print(subsample_4.shape)
print(subsample_5.shape)
print(subsample_6.shape)
print(subsample_7.shape)
print(subsample_8.shape)
# Out:
# (285, 321)
# (155, 321)
# (49, 321)
# (111, 321)
# (253, 321)
# (207, 321)
# (6, 321)
# (37, 321)

# %%
combined_subsamples_2000 = np.concatenate((subsample_1, subsample_2, subsample_3, subsample_4, \
                                     subsample_5, subsample_6, subsample_7, subsample_8, means))
print(combined_subsamples_2000.shape)
# Out:
# (1111, 321)

# %%
model = TSNE(learning_rate = 75)
transformed_75 = model.fit_transform(combined_subsamples_2000)
transformed_means = model.fit_transform(means)
print(transformed_75.shape)
xs_75 = transformed_75[:,0]
ys_75 = transformed_75[:,1]
# Out:
# C:\Users\vpatro\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\vpatro\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# (1111, 2)

# %%
plt.scatter(xs_75[0:285],ys_75[0:285],color='red', alpha = 0.7)
plt.scatter(xs_75[285:440],ys_75[285:440],color='blue', alpha = 0.7)
plt.scatter(xs_75[440:489],ys_75[440:489],color='green', alpha = 0.7)
plt.scatter(xs_75[489:600],ys_75[489:600],color='purple', alpha = 0.7)
plt.scatter(xs_75[600:853],ys_75[600:853],color='orange', alpha = 0.7)
plt.scatter(xs_75[853:1060],ys_75[853:1060],color='yellow', alpha = 0.7)
plt.scatter(xs_75[1060:1066],ys_75[1060:1066],color='pink', alpha = 0.7)
plt.scatter(xs_75[1066:1103],ys_75[1066:1103],color='aquamarine', alpha = 0.7)
plt.scatter(xs_75[1103:1111],ys_75[1103:1111],color='black', alpha = 0.7)
plt.title('Learning Rate 75, 1111 samples')
# Out:
# Text(0.5, 1.0, 'Learning Rate 75, 1111 samples')

# %%
combined_subsamples_2000.shape
# Out:
# (1111, 321)

# %%
model = TSNE(learning_rate = 150)
transformed_150 = model.fit_transform(combined_subsamples_2000)
print(transformed_150.shape)
xs_150 = transformed_150[:,0]
ys_150 = transformed_150[:,1]
# Out:
# C:\Users\vpatro\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# (1111, 2)

# %%
plt.scatter(xs_150[0:285],ys_150[0:285],color='red', alpha = 0.7)
plt.scatter(xs_150[285:440],ys_150[285:440],color='blue', alpha = 0.7)
plt.scatter(xs_150[440:489],ys_150[440:489],color='green', alpha = 0.7)
plt.scatter(xs_150[489:600],ys_150[489:600],color='purple', alpha = 0.7)
plt.scatter(xs_150[600:853],ys_150[600:853],color='orange', alpha = 0.7)
plt.scatter(xs_150[853:1060],ys_150[853:1060],color='yellow', alpha = 0.7)
plt.scatter(xs_150[1060:1066],ys_150[1060:1066],color='pink', alpha = 0.7)
plt.scatter(xs_150[1066:1103],ys_150[1066:1103],color='aquamarine', alpha = 0.7)
plt.scatter(xs_150[1103:1111],ys_150[1103:1111],color='black', alpha = 0.7)
plt.title('Learning Rate 150, 1111 samples')
# Out:
# Text(0.5, 1.0, 'Learning Rate 150, 1111 samples')

# %%
subsample_1_ind = np.arange(0,cluster_1.shape[0],1000)
subsample_1 = cluster_1[subsample_1_ind,:].copy()
subsample_2_ind = np.arange(0,cluster_2.shape[0],1000)
subsample_2 = cluster_2[subsample_2_ind,:].copy()
subsample_3_ind = np.arange(0,cluster_3.shape[0],1000)
subsample_3 = cluster_3[subsample_3_ind,:].copy()
subsample_4_ind = np.arange(0,cluster_4.shape[0],1000)
subsample_4 = cluster_4[subsample_4_ind,:].copy()
subsample_5_ind = np.arange(0,cluster_5.shape[0],1000)
subsample_5 = cluster_5[subsample_5_ind,:].copy()
subsample_6_ind = np.arange(0,cluster_6.shape[0],1000)
subsample_6 = cluster_6[subsample_6_ind,:].copy()
subsample_7_ind = np.arange(0,cluster_7.shape[0],1000)
subsample_7 = cluster_7[subsample_7_ind,:].copy()
subsample_8_ind = np.arange(0,cluster_8.shape[0],1000)
subsample_8 = cluster_8[subsample_8_ind,:].copy()

# %%
print(subsample_1.shape)
print(subsample_2.shape)
print(subsample_3.shape)
print(subsample_4.shape)
print(subsample_5.shape)
print(subsample_6.shape)
print(subsample_7.shape)
print(subsample_8.shape)
# Out:
# (569, 321)
# (310, 321)
# (97, 321)
# (221, 321)
# (505, 321)
# (413, 321)
# (11, 321)
# (73, 321)

# %%
combined_subsamples_1000 = np.concatenate((subsample_1, subsample_2, subsample_3, subsample_4, \
                                     subsample_5, subsample_6, subsample_7, subsample_8, means))
print(combined_subsamples_1000.shape)
# Out:
# (2207, 321)

# %%
model_default = TSNE()
transformed = model_default.fit_transform(combined_subsamples_1000)
print(transformed.shape)
x = transformed[:,0]
y = transformed[:,1]
# Out:
# C:\Users\vpatro\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\vpatro\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# (2207, 2)

# %%
plt.scatter(x[0:569],y[0:569],color='red', alpha = 0.6)
plt.scatter(x[569:879],y[569:879],color='blue', alpha = 0.6)
plt.scatter(x[879:976],y[879:976],color='green', alpha = 0.6)
plt.scatter(x[976:1197],y[976:1197],color='purple', alpha = 0.6)
plt.scatter(x[1197:2502],y[1197:2502],color='orange', alpha = 0.6)
plt.scatter(x[1702:2115],y[1702:2115],color='yellow', alpha = 0.6)
plt.scatter(x[2115:2126],y[2115:2126],color='pink', alpha = 0.6)
plt.scatter(x[2126:2199],y[2126:2199],color='aquamarine', alpha = 0.6)
plt.scatter(x[2199:2207],y[2199:2207],color='black', alpha = 0.6)
plt.title('Defaut LR, 2207 Samples')
# Out:
# Text(0.5, 1.0, 'Defaut LR, 2207 Samples')

# %%
combined_subsamples.shape
# Out:
# (563, 321)

# %%
model = TSNE()
transformed = model.fit_transform(combined_subsamples)
print(transformed.shape)
x = transformed[:,0]
y = transformed[:,1]
# Out:
# C:\Users\vpatro\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\vpatro\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# (563, 2)

# %%
transformed.shape
# Out:
# (563, 2)

# %%
plt.scatter(x[0:143],y[0:143],color='red', alpha = 0.7)
plt.scatter(x[143:221],y[143:221],color='blue', alpha = 0.7)
plt.scatter(x[221:246],y[221:246],color='green', alpha = 0.7)
plt.scatter(x[246:302],y[246:302],color='purple', alpha = 0.7)
plt.scatter(x[302:429],y[302:429],color='orange', alpha = 0.7)
plt.scatter(x[429:533],y[429:533],color='yellow', alpha = 0.7)
plt.scatter(x[533:536],y[533:536],color='pink', alpha = 0.7)
plt.scatter(x[536:555],y[536:555],color='aquamarine', alpha = 0.7)
plt.scatter(x[555:563],y[555:563],color='black', alpha = 0.7)
plt.title('Default LR, 563 Samples')
# Out:
# Text(0.5, 1.0, 'Default LR, 563 Samples')
