# %%
import numpy as np
from scipy.linalg import norm, eig
import time
from geoarray import GeoArray
import scipy
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
import tkinter
import matplotlib
matplotlib.use('TkAgg')
# %matplotlib inline

# %%
def remove_bad_bands(spectra: np.array):
    bands = list(range(1,426))
    bands = np.array(bands)
    deeph2o = np.logical_or(np.logical_and(bands > 181, bands < 224), np.logical_and(bands > 275, bands < 329))
    bad_cal = bands > 418
    bad = np.logical_or(deeph2o, bad_cal)
    spectra[bad] = np.nan
    
def zero_bad_bands(spectra: np.array):
    bands = list(range(1,426))
    bands = np.array(bands)
    deeph2o = np.logical_or(np.logical_and(bands > 181, bands < 224), np.logical_and(bands > 275, bands < 329))
    bad_cal = bands > 418
    bad = np.logical_or(deeph2o, bad_cal)
    spectra[bad] = 0

# %%
Kurnool_India = GeoArray(r'C:\\Users\\vpatro\\Desktop\\ang20160126\\ang20160126t055327_corr_v2m2_img')
print('Shape of Kurnool, India: ', Kurnool_India.shape)
Pavicharam_India = GeoArray(r'C:\\Users\\vpatro\\Desktop\\ang20180318t060114\ang20180318t060114_corr_v2s1_img')
print('Shape of Pavicharam, India: ', Pavicharam_India.shape)
SF_bay = GeoArray(r'C:\\Users\\vpatro\\Desktop\\ang20181009t191224\\ang20181009t191224_corr_v2t1_img')
print('Shape of SF Bay: ', SF_bay.shape)
# Out:
# Shape of Kurnool, India:  (5618, 704, 425)
# Shape of Pavicharam, India:  (5130, 680, 425)
# Shape of SF Bay:  (3998, 670, 425)

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 3, figsize = (6,12), constrained_layout = True)
im = axs[0].imshow(SF_bay[:,:,50])
plt.colorbar(im, ax = axs[0])
im.set_clim(0,0.2)
im2 = axs[1].imshow(Pavicharam_India[:,:,50])
plt.colorbar(im2, ax = axs[1])
im2.set_clim(0,0.2)
im3 = axs[2].imshow(Kurnool_India[:,:,50])
plt.colorbar(im3, ax = axs[2])
im3.set_clim(0,0.2)

# %%
 # removing peripheral pushbroom effects
start_time = time.time()
Kurnool_India = Kurnool_India[1000:4000, 150:600, :]
print("--- %s seconds ---" % (time.time() - start_time))
print(Kurnool_India.shape)
# Out:
# --- 71.60485315322876 seconds ---
# (3000, 450, 425)

# %%
start_time = time.time()
Pavicharam_India = Pavicharam_India[75:2500, 200:600, :]
print("--- %s seconds ---" % (time.time() - start_time))
print(Pavicharam_India.shape)
# Out:
# --- 13.603461980819702 seconds ---
# (2425, 400, 425)

# %%
start_time = time.time()
SF_bay = SF_bay[1200:2700, 150:500, :]
print("--- %s seconds ---" % (time.time() - start_time))
print(SF_bay.shape)
# Out:
# --- 38.32292723655701 seconds ---
# (1500, 350, 425)

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 3, figsize = (6,12), constrained_layout = True)
im = axs[0].imshow(SF_bay[:,:,50])
plt.colorbar(im, ax = axs[0])
im.set_clim(0,0.2)
im2 = axs[1].imshow(Pavicharam_India[:,:,50])
plt.colorbar(im2, ax = axs[1])
im2.set_clim(0,0.2)
im3 = axs[2].imshow(Kurnool_India[:,:,50])
plt.colorbar(im3, ax = axs[2])
im3.set_clim(0,0.2)

# %%
Kurnool_India = Kurnool_India.reshape(Kurnool_India.shape[0]*Kurnool_India.shape[1], Kurnool_India.shape[2])
print('reshapen Kurnool_India: ', Kurnool_India.shape)
Pavicharam_India = Pavicharam_India.reshape(Pavicharam_India.shape[0]*Pavicharam_India.shape[1], Pavicharam_India.shape[2])
print('reshapen Pavicharam_India: ', Pavicharam_India.shape)
SF_bay = SF_bay.reshape(SF_bay.shape[0]*SF_bay.shape[1], SF_bay.shape[2])
print('reshapen SF_bay: ', SF_bay.shape)
# Out:
# reshapen Kurnool_India:  (1350000, 425)
# reshapen Pavicharam_India:  (970000, 425)
# reshapen SF_bay:  (525000, 425)

# %%
combined = np.concatenate((Kurnool_India, Pavicharam_India, SF_bay), axis = 0)

# %%
combined.shape
# Out:
# (2845000, 425)

# %%
# visualizing covariance matrix - why is it that we only need every 40th?
copied = combined.copy()
subsample = np.arange(0,copied.shape[0],60) # gathering indices we want
X_sub = copied[subsample,:].copy()
Cov = np.cov(X_sub, rowvar = False)

plt.imshow(Cov)
plt.colorbar()
plt.clim(0,0.02)
plt.title('Covariance Matrix')
# Out:
# Text(0.5, 1.0, 'Covariance Matrix')

# %%
# eigenvector analysis
eigenvalues, eigenvectors = eig(Cov)
noise = np.zeros(50)
plt.plot(np.arange(50), np.log10(eigenvalues[:50]), label = 'Eigenvalues', marker = 'o')
plt.plot(noise, label = 'Noise', marker = 'o')
plt.title('Eigenvalue Decay')
plt.xlabel('Component')
plt.ylabel('Log eigenvalue')
plt.legend()
# Out:
# C:\Users\vpatro\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
combined.shape
# Out:
# (2845000, 425)

# %%
# clustering takes a little over 3 min
start_time = time.time()
seed = 8
kmeans_4 = KMeans(init='k-means++', n_clusters = 4, n_init=10, random_state=seed).fit(combined)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 247.69436740875244 seconds ---

# %%
Z_4 = kmeans_4.predict(combined)
clusterCount_4 = np.bincount(kmeans_4.labels_)
print(clusterCount_4)
# Out:
# [2844997       1       1       1]

# %%
means_4 = kmeans_4.cluster_centers_
print(means_4[0])
means_4_no_nan = means_4.copy()
for i in range(means_4.shape[0]):
    remove_bad_bands(means_4[i])
    plt.plot(means_4[i], label = 'Mean ' + str(i+1))
plt.legend()
# Out:
# [ 1.54714296e-02  2.26671584e-02  2.58990414e-02  2.83052120e-02
#   2.97649205e-02  3.31017375e-02  3.44827324e-02  3.59691642e-02
#   3.74961309e-02  3.88739370e-02  4.07604463e-02  4.40315120e-02
#   4.41294126e-02  4.64696623e-02  4.89939861e-02  5.06281964e-02
#   5.28004952e-02  5.55137172e-02  5.65204993e-02  5.82915433e-02
#   5.99479564e-02  6.22617751e-02  6.39083087e-02  6.47671595e-02
#   6.61519095e-02  6.74090385e-02  6.78823814e-02  7.02467710e-02
#   7.33183920e-02  7.50887468e-02  7.79017434e-02  8.03865343e-02
#   8.22867379e-02  8.33026394e-02  8.47618878e-02  8.66117328e-02
#   8.74331146e-02  8.77630785e-02  8.80706012e-02  8.78526792e-02
#   8.76556039e-02  8.78140330e-02  8.90021026e-02  8.97654220e-02
#   8.87733847e-02  8.77961367e-02  8.76132697e-02  8.77156705e-02
#   8.77178162e-02  8.78033638e-02  8.83407518e-02  8.90836790e-02
#   8.96306857e-02  9.02608112e-02  9.14849862e-02  9.20198262e-02
#   9.21390131e-02  9.17278752e-02  9.20976996e-02  9.22093689e-02
#   9.26103219e-02  9.39510316e-02  9.60472748e-02  9.93823931e-02
#   1.04186192e-01  1.10001333e-01  1.15828432e-01  1.22570604e-01
#   1.30863145e-01  1.39275655e-01  1.47029817e-01  1.53120473e-01
#   1.58679977e-01  1.63862601e-01  1.68304190e-01  1.71700537e-01
#   1.75047755e-01  1.76053599e-01  1.77554920e-01  1.80420011e-01
#   1.82099164e-01  1.83736682e-01  1.84853345e-01  1.86360985e-01
#   1.87807962e-01  1.89729944e-01  1.90746531e-01  1.91620022e-01
#   1.93952724e-01  1.94202840e-01  1.94917917e-01  1.95172563e-01
#   1.95589513e-01  1.96804196e-01  1.97689205e-01  1.98681325e-01
#   1.99230626e-01  1.99804232e-01  2.00604573e-01  2.00976476e-01
#   2.01989561e-01  2.02778369e-01  2.03703120e-01  2.03695625e-01
#   2.05154791e-01  2.06320465e-01  2.06929445e-01  2.07573265e-01
#   2.08968803e-01  2.09154084e-01  2.10058868e-01  2.28134811e-01
#   2.27253675e-01  2.16565937e-01  2.16369823e-01  2.15172678e-01
#   2.11076453e-01  2.08669350e-01  2.07148850e-01  2.07830399e-01
#   2.08878919e-01  2.08089411e-01  2.09442928e-01  2.10687324e-01
#   2.11892247e-01  2.14788988e-01  2.16012031e-01  2.17039302e-01
#   2.18382999e-01  2.19612002e-01  2.20612049e-01  2.21579581e-01
#   2.22694606e-01  2.23643735e-01  2.24359393e-01  2.24766195e-01
#   2.25690797e-01  2.26123512e-01  2.26639688e-01  2.27312967e-01
#   2.27640629e-01  2.28115425e-01  2.28908196e-01  2.29176491e-01
#   2.29230225e-01  2.29512304e-01  2.26953387e-01  2.24586084e-01
#   2.38007188e-01  2.58698225e-01  2.38750845e-01  2.13517278e-01
#   2.01325998e-01  2.11759835e-01  2.16610208e-01  2.10683525e-01
#   2.05906853e-01  2.05517575e-01  2.07433894e-01  2.09197670e-01
#   2.11008236e-01  2.11685374e-01  2.12072209e-01  2.12258443e-01
#   2.13961393e-01  2.12073386e-01  2.11075872e-01  2.11968809e-01
#   2.12818056e-01  2.13957101e-01  2.14909032e-01  2.15628579e-01
#   2.16548204e-01  2.17491835e-01  2.18289912e-01  2.18853414e-01
#   2.18823269e-01  2.19068602e-01  2.19373778e-01  2.19579473e-01
#   2.19821915e-01  2.19627619e-01  2.19267279e-01  2.18124479e-01
#   2.18232274e-01  2.18260825e-01  2.16875464e-01  2.15625823e-01
#   2.11209983e-01  2.07987159e-01  2.06856921e-01  1.99648231e-01
#   1.93007827e-01  1.76903531e-01  1.64480641e-01 -4.97586399e-01
#   1.91501026e+01  2.22904129e+01  2.24506416e+01  1.78965816e+01
#   1.62396851e+01  1.98757420e+01  1.69014988e+01  1.63648853e+01
#   1.25902624e+01  1.00171785e+01  6.32760811e+00  1.87720466e+00
#   1.44214201e+00  6.10259473e-01  2.57109642e-01  2.52688229e-01
#   2.64338732e-01  2.23121360e-01  1.55199334e-01  1.44342676e-01
#   1.36767074e-01  1.41975135e-01  1.55555233e-01  1.39189333e-01
#   1.42315552e-01  1.48027003e-01  1.48895368e-01  1.49109408e-01
#   1.50772348e-01  1.54790565e-01  1.55693650e-01  1.58263072e-01
#   1.60571635e-01  1.61564723e-01  1.63956255e-01  1.65298566e-01
#   1.67275146e-01  1.68409526e-01  1.69428319e-01  1.70637533e-01
#   1.72104806e-01  1.73499942e-01  1.74293250e-01  1.75106063e-01
#   1.76251650e-01  1.77569956e-01  1.78925753e-01  1.80119410e-01
#   1.81172177e-01  1.82066083e-01  1.82963669e-01  1.84005395e-01
#   1.85012475e-01  1.85834840e-01  1.86706275e-01  1.87534198e-01
#   1.88121274e-01  1.88841611e-01  1.89107537e-01  1.89315379e-01
#   1.89305484e-01  1.89250425e-01  1.88620716e-01  1.88478813e-01
#   1.88273177e-01  1.87692255e-01  1.86933741e-01  1.86143994e-01
#   1.85351923e-01  1.84393227e-01  1.83674082e-01  1.82496488e-01
#   1.80970058e-01  1.79516897e-01  1.78963751e-01  1.78003609e-01
#   1.78080902e-01  1.76690891e-01  1.75228626e-01  1.73599795e-01
#   1.71054751e-01  1.68515250e-01  1.64770991e-01  1.61029205e-01
#   1.60050124e-01  1.56779572e-01  1.47698075e-01  1.48376241e-01
#   1.54748067e-01  1.46407768e-01  1.87860250e-01  6.35548949e-01
#   4.17684317e+00  4.78879452e+00  1.23671408e+01  3.24187737e+01
#   3.35932503e+01  3.33404770e+01  3.24890442e+01  3.32755966e+01
#   3.17181549e+01  3.07284603e+01  3.19311275e+01  3.21846657e+01
#   2.82691116e+01  2.49960899e+01  2.11301632e+01  1.99815159e+01
#   2.49740906e+01  3.68137169e+01  3.35819588e+01  2.75267258e+01
#   2.24469090e+01  9.25216675e+00  7.61638498e+00  2.25821161e+00
#   3.53065908e-01  2.09429815e-01  1.46022975e-01  1.41765654e-01
#   1.35000840e-01  1.14995100e-01  1.07317612e-01  1.10077441e-01
#   1.13185227e-01  1.14892513e-01  1.14778966e-01  1.16086356e-01
#   1.18142016e-01  1.24763452e-01  1.21038824e-01  1.23846814e-01
#   1.22688405e-01  1.21848188e-01  1.24055721e-01  1.25967383e-01
#   1.27169043e-01  1.28488541e-01  1.29014134e-01  1.29857719e-01
#   1.30950168e-01  1.30963802e-01  1.30434990e-01  1.30417958e-01
#   1.31222740e-01  1.31628245e-01  1.31874412e-01  1.32566184e-01
#   1.33867264e-01  1.33476749e-01  1.33666217e-01  1.33733913e-01
#   1.34796947e-01  1.34597689e-01  1.34623140e-01  1.34465098e-01
#   1.34467483e-01  1.34177908e-01  1.35228053e-01  1.35259241e-01
#   1.34068981e-01  1.33773923e-01  1.33827657e-01  1.33768171e-01
#   1.33124620e-01  1.33477166e-01  1.32857248e-01  1.31105036e-01
#   1.30416527e-01  1.29696235e-01  1.30407348e-01  1.30404383e-01
#   1.29887626e-01  1.29702672e-01  1.28874302e-01  1.27277181e-01
#   1.25269040e-01  1.23389900e-01  1.21637687e-01  1.20083168e-01
#   1.18519448e-01  1.16694301e-01  1.14825092e-01  1.13479145e-01
#   1.11958727e-01  1.10540010e-01  1.08904630e-01  1.06775187e-01
#   1.05470881e-01  1.03877589e-01  1.02000624e-01  1.00641236e-01
#   9.91176590e-02  9.82405469e-02  9.66258869e-02  9.55387056e-02
#   9.43204314e-02  9.19201374e-02  9.08562988e-02  9.00572613e-02
#   8.82091969e-02  8.67536068e-02  8.66121501e-02  8.37924704e-02
#   8.28062296e-02  8.24768618e-02  8.00296366e-02  7.84564689e-02
#   7.60964155e-02  7.46961758e-02  7.38448501e-02  7.58843943e-02
#   7.04596639e-02  6.67545348e-02  6.26936182e-02  6.52309135e-02
#   5.72325811e-02  5.99016510e-02  7.31025189e-02  5.34524061e-02
#   4.99018729e-02  5.01560234e-02  5.67137972e-02  5.83590530e-02
#   9.16259363e-02  5.76389611e-01  1.05275536e+00  3.47919554e-01
#   1.53584182e-01]

# %%
combined.shape
# Out:
# (2845000, 425)

# %%
# clustering takes a little over 6 min
start_time = time.time()
seed = 8
kmeans_6 = KMeans(init='k-means++', n_clusters = 6, n_init=10, random_state=seed).fit(combined)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 382.3384268283844 seconds ---

# %%
Z_6 = kmeans_6.predict(combined)
clusterCount_6 = np.bincount(kmeans_6.labels_)
print(clusterCount_6)
# Out:
# [2844994       1       1       1       2       1]

# %%
means_6 = kmeans_6.cluster_centers_
means_6_no_nan = means_6.copy()
for i in range(means_6.shape[0]):
    remove_bad_bands(means_6[i])
    plt.plot(means_6[i], label = 'Mean ' + str(i+1))
plt.legend()

# %%
from scipy.cluster.vq import vq
start_time = time.time()
nearest_cluster, distance_to = vq(combined, means_4_no_nan)

print(nearest_cluster)
print(distance_to)

"""

ERROR: ValueError: array must not contain infs or NaNs


from sklearn.metrics import pairwise_distances_argmin_min
start_time = time.time()
nearest_cluster, distance_to = pairwise_distances_argmin_min(means_6, combined)
print("--- %s seconds ---" % (time.time() - start_time))

ERROR: ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

"""
# Out:
# [0 0 0 ... 0 0 0]
# [ 66.222534  65.67865   66.836334 ... 100.18455  107.92355  102.42172 ]
# '\n\nERROR: ValueError: array must not contain infs or NaNs\n\n\nfrom sklearn.metrics import pairwise_distances_argmin_min\nstart_time = time.time()\nnearest_cluster, distance_to = pairwise_distances_argmin_min(means_6, combined)\nprint("--- %s seconds ---" % (time.time() - start_time))\n\nERROR: ValueError: Input contains NaN, infinity or a value too large for dtype(\'float32\').\n\n'

# %%
for i in range(nearest_cluster.shape[0]):
    if nearest_cluster[i] == 1:
        print('index of point closest to cluster 1: ', i)
        print('distance to cluster 1: ', distance_to[i])
    if nearest_cluster[i] == 2:
        print('index of point closest to cluster 2: ', i)
        print('distance to cluster 1: ', distance_to[i])
    if nearest_cluster[i] == 3:
        print('index of point closest to cluster 3: ', i)
        print('distance to cluster 1: ', distance_to[i])
# Out:
# index of point closest to cluster 3:  2344621
# distance to cluster 1:  0.0
# index of point closest to cluster 2:  2460002
# distance to cluster 1:  0.0
# index of point closest to cluster 1:  2676728
# distance to cluster 1:  0.0

# %%
point_indices, distances_to = vq(means_4_no_nan, combined)
print('indices of points: ', point_indices)
print('distances of those points', distances_to)
# Out:
# indices of points:  [ 946356 2676728 2460002 2344621]
# distances of those points [41.028168  0.        0.        0.      ]

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize = (10,4), constrained_layout = True)
gs = fig.add_gridspec()
axs[0].plot(combined[2676728])
axs[0].plot(combined[2460002])
axs[0].plot(combined[2344621])
axs[0].set_ylim(0,0.5)
axs[1].plot(combined[2676728])
axs[1].plot(combined[2460002])
axs[1].plot(combined[2344621])

# %%
shortened_combined = combined[:, :150].copy()
print(shortened_combined.shape)
print(combined.shape)
# Out:
# (2845000, 150)
# (2845000, 425)

# %%
start_time = time.time()
seed = 8
kmeans_4 = KMeans(init='k-means++', n_clusters = 4, n_init=10, random_state=seed).fit(shortened_combined)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 263.7731828689575 seconds ---

# %%
Z_4 = kmeans_4.predict(shortened_combined)
clusterCount_4 = np.bincount(kmeans_4.labels_)
print(clusterCount_4)
# Out:
# [748773 884939 666767 544521]

# %%
means_4 = kmeans_4.cluster_centers_
#print(means_4[0])
means_4_no_nan = means_4.copy()
for i in range(means_4.shape[0]):
    #remove_bad_bands(means_4[i])
    plt.plot(means_4[i], label = 'Mean ' + str(i+1))
plt.legend()

# %%
bands = list(range(1,426))
bands = np.array(bands)
deeph2o = np.logical_or(np.logical_and(bands > 181, bands < 224), np.logical_and(bands > 275, bands < 329))
bad_cal = bands > 418
bad = np.logical_or(deeph2o, bad_cal)
combined[:, bad] = np.nan

# %%
combined.shape
# Out:
# (2845000, 425)

# %%
use = np.all(np.isfinite(combined), axis = 0)
combined = combined[:, use]
print(combined.shape)
# Out:
# (2845000, 323)

# %%
# Running k means on reduced array
start_time = time.time()
seed = 8
kmeans_4 = KMeans(init='k-means++', n_clusters = 4, n_init=10, random_state=seed).fit(combined)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 482.3128032684326 seconds ---

# %%
Z_4 = kmeans_4.predict(combined)
clusterCount_4 = np.bincount(kmeans_4.labels_)
print(clusterCount_4)
# Out:
# [802375 785374 519009 738242]

# %%
means_4 = kmeans_4.cluster_centers_

# %%
means_4.shape
# Out:
# (4, 323)

# %%
means_4 = kmeans_4.cluster_centers_
for i in range(means_4.shape[0]):
    plt.plot(means_4[i], label = 'Mean ' + str(i+1))
plt.legend()

# %%
plt.plot(means_4_no_nan[0], label = 'Mean 1')
plt.plot(means_4_no_nan[1], label = 'Mean 2')
plt.plot(means_4_no_nan[2], label = 'Mean 3')
plt.plot(means_4_no_nan[3], label = 'Mean 4')
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
from scipy.spatial import distance
closest_ind = 0
min_dist = np.inf
for i in range(combined.shape[0]):
    x = distance.euclidean(means_4_no_nan[1], combined[i])
    if x < min_dist:
        closest_ind = i
        min_dist = x
        
print('closest spectra: ' + str(closest_ind))
print('distance: ' + str(min_dist))
# Out:
# closest spectra: 2676728
# distance: 9.020127436087932e-07

# %%
plt.plot(combined[2844999], label = 'second to last')
plt.plot(means_4_no_nan[1], label = 'mean 2')
plt.plot(combined[2676728])
plt.ylim(0,1)
plt.legend()

# %%
distance.euclidean(means_4_no_nan[0], combined[2844999])
# Out:
# 102.42174530029297

# %%
plt.plot(combined[2844999])
plt.plot(combined[2676728])
plt.ylim(0,1)
# Out:
# (0.0, 1.0)
