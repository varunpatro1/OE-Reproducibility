# %%
import numpy as np
from scipy.linalg import norm, eig
import time
from geoarray import GeoArray
import scipy
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
import tkinter
import matplotlib
matplotlib.use('TkAgg')
# %matplotlib inline

# %%
images = []

# %%
Kurnool_India = GeoArray(r'C:\\Users\\vpatro\\Desktop\\ang20160126\\ang20160126t055327_corr_v2m2_img')
print('Kurnool, India: ', Kurnool_India.shape)
images.append(Kurnool_India)
Pavicharam_India = GeoArray(r'C:\\Users\\vpatro\\Desktop\\ang20180318t060114\ang20180318t060114_corr_v2s1_img')
print('Pavicharam, India: ', Pavicharam_India.shape)
images.append(Pavicharam_India)
SF_bay = GeoArray(r'C:\\Users\\vpatro\\Desktop\\ang20181009t191224\\ang20181009t191224_corr_v2t1_img')
print('SF Bay: ', SF_bay.shape)
images.append(SF_bay)
Tulsa_OK = GeoArray(r'C:\\Users\\vpatro\\Desktop\\ang20191027t160833\\ang20191027t160833_corr_v2x1_img')
print('Tulsa, OK: ', Tulsa_OK.shape)
images.append(Tulsa_OK)
Munich_Ger = GeoArray(r'C:\\Users\\vpatro\\Desktop\\ang20180702t105516\\ang20180702t105516_corr_v2q2_img')
print('Munich, Germany: ', Munich_Ger.shape)
images.append(Munich_Ger)
Holstein_Switz = GeoArray(r'C:\\Users\\vpatro\\Desktop\\ang20180630t083756\\ang20180630t083756_corr_v2q2_img')
print('Holstein, Switzerland: ', Holstein_Switz.shape)
images.append(Holstein_Switz)
# Out:
# Kurnool, India:  (5618, 704, 425)
# Pavicharam, India:  (5130, 680, 425)
# SF Bay:  (3998, 670, 425)
# Tulsa, OK:  (2446, 640, 425)
# Munich, Germany:  (1673, 649, 425)
# Holstein, Switzerland:  (1729, 658, 425)

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 6, figsize = (12,24), constrained_layout = True)
for i in range(6):
    im = axs[i].imshow(images[i][:,:,50])
    plt.colorbar(im, ax = axs[i])
    im.set_clim(0,0.2)

# %%
cut_images = []

# %%
start_time = time.time()
Kurnool_India = Kurnool_India[2200:2900, 250:500, :]
print("--- %s seconds ---" % (time.time() - start_time))
cut_images.append(Kurnool_India)
print(Kurnool_India.shape)

start_time = time.time()
Pavicharam_India = Pavicharam_India[800:1600, 300:550, :]
print("--- %s seconds ---" % (time.time() - start_time))
cut_images.append(Pavicharam_India)
print(Pavicharam_India.shape)

start_time = time.time()
SF_bay = SF_bay[1450:2400, 250:400, :]
print("--- %s seconds ---" % (time.time() - start_time))
cut_images.append(SF_bay)

print(SF_bay.shape)
# Out:
# --- 3.521199941635132 seconds ---
# (700, 250, 425)
# --- 3.640549421310425 seconds ---
# (800, 250, 425)
# --- 4.517041206359863 seconds ---
# (950, 150, 425)

# %%
start_time = time.time()
Tulsa_OK = Tulsa_OK[400:1000, 100:400, :]
print("--- %s seconds ---" % (time.time() - start_time))
cut_images.append(Tulsa_OK)

print(Tulsa_OK.shape)

start_time = time.time()
Munich_Ger = Munich_Ger[250:1500, 100:550, :]
print("--- %s seconds ---" % (time.time() - start_time))
cut_images.append(Munich_Ger)

print(Munich_Ger.shape)

start_time = time.time()
Holstein_Switz = Holstein_Switz[1000:1500, 100:600, :]
print("--- %s seconds ---" % (time.time() - start_time))
cut_images.append(Holstein_Switz)
print(Holstein_Switz.shape)
# Out:
# --- 2.309126138687134 seconds ---
# (600, 300, 425)
# --- 4.879950046539307 seconds ---
# (1250, 450, 425)
# --- 1.9370613098144531 seconds ---
# (500, 500, 425)

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 6, figsize = (12,24), constrained_layout = True)
for i in range(6):
    im = axs[i].imshow(cut_images[i][:,:,50])
    plt.colorbar(im, ax = axs[i])
    im.set_clim(0,0.2)
